# %% [markdown]
# <a href="https://colab.research.google.com/github/sandhya197/EDA-on-football-data/blob/main/foot_ball.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa=pd.read_csv('/content/players_20.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
for c in fifa.columns:
  print(c)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
h=fifa['nationality'].value_counts()[0:5]

# %%
l=fifa['nationality'].value_counts()[0:5].keys()

# %%
plt.figure(figsize=(10,5))
plt.bar(list(l),list(h),color="c")
# Out:
# <BarContainer object of 5 artists>

# %%
salary=fifa[['short_name','wage_eur']]

# %%
salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
salary=salary.sort_values(by=['wage_eur'],ascending=False)

# %%
salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize=(10,5))
plt.bar(list(salary['short_name'])[0:5],list(salary['wage_eur'])[0:5],color=["red","pink","cyan","blue","green"])
plt.show()

# %%
fifa['nationality']=='England'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
eng=fifa[fifa['nationality']=='England']
eng.head(10)
# Out:
#      sofifa_id                                         player_url  \
# 12      202126  https://sofifa.com/player/202126/harry-kane/20...
# 26      202652  https://sofifa.com/player/202652/raheem-sterli...
# 108     233049  https://sofifa.com/player/233049/jadon-sancho/...
# 113     211117  https://sofifa.com/player/211117/dele-alli/20/...
# 148     188377  https://sofifa.com/player/188377/kyle-walker/2...
# 160     231281  https://sofifa.com/player/231281/trent-alexand...
# 171     231677  https://sofifa.com/player/231677/marcus-rashfo...
# 172     203574  https://sofifa.com/player/203574/john-stones/2...
# 181     204935  https://sofifa.com/player/204935/jordan-pickfo...
# 218     183711  https://sofifa.com/player/183711/jordan-hender...
#
#               short_name               long_name  age         dob  height_cm  \
# 12               H. Kane              Harry Kane   25  1993-07-28        188
# 26           R. Sterling         Raheem Sterling   24  1994-12-08        170
# ...

# %%
eng.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 12808     215408  https://sofifa.com/player/215408/aaron-chapman...
# 17365     241870  https://sofifa.com/player/241870/matt-casey/20...
# 3014      172203  https://sofifa.com/player/172203/fraser-forste...
# 628       203841  https://sofifa.com/player/203841/nick-pope/20/...
# 11526     223069  https://sofifa.com/player/223069/omar-sowunmi/...
#
#        short_name       long_name  age         dob  height_cm  weight_kg  \
# 12808  A. Chapman   Aaron Chapman   29  1990-05-29        203         92
# 17365    M. Casey      Matt Casey   19  1999-11-13        203         80
# 3014   F. Forster  Fraser Forster   31  1988-03-17        201         93
# 628       N. Pope       Nick Pope   27  1992-04-19        200         76
# 11526  O. Sowunmi    Omar Sowunmi   23  1995-11-07        199         93
#
#       nationality                 club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %%
eng.sort_values(by=['weight_kg'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 10693     156321  https://sofifa.com/player/156321/adebayo-akinf...
# 280       203263  https://sofifa.com/player/203263/harry-maguire...
# 5266      163600  https://sofifa.com/player/163600/john-ruddy/20...
# 6960      202770  https://sofifa.com/player/202770/connor-ripley...
# 8439      183138  https://sofifa.com/player/183138/krystian-pear...
#
#          short_name          long_name  age         dob  height_cm  weight_kg  \
# 10693  A. Akinfenwa  Adebayo Akinfenwa   37  1982-05-10        178        110
# 280      H. Maguire      Harry Maguire   26  1993-03-05        194        100
# 5266       J. Ruddy         John Ruddy   32  1986-10-24        193         97
# 6960      C. Ripley      Connor Ripley   26  1993-02-13        191         96
# 8439      K. Pearce    Krystian Pearce   29  1990-01-05        188         95
#
#       nationality                     club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %%
eng.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 26      202652  https://sofifa.com/player/202652/raheem-sterli...
# 12      202126  https://sofifa.com/player/202126/harry-kane/20...
# 148     188377  https://sofifa.com/player/188377/kyle-walker/2...
# 172     203574  https://sofifa.com/player/203574/john-stones/2...
# 319     207494  https://sofifa.com/player/207494/jesse-lingard...
#
#       short_name        long_name  age         dob  height_cm  weight_kg  \
# 26   R. Sterling  Raheem Sterling   24  1994-12-08        170         69
# 12       H. Kane       Harry Kane   25  1993-07-28        188         89
# 148    K. Walker      Kyle Walker   29  1990-05-28        183         70
# 172    J. Stones      John Stones   25  1994-05-28        188         70
# 319   J. Lingard    Jesse Lingard   26  1992-12-15        175         62
#
#     nationality               club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
eng[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#       short_name  wage_eur
# 26   R. Sterling    255000
# 12       H. Kane    220000
# 148    K. Walker    165000
# 172    J. Stones    140000
# 319   J. Lingard    135000

# %%
p=fifa[['short_name','skill_moves']]

# %%
p.sort_values(by=['skill_moves'],ascending=False).head(10)
# Out:
#              short_name  skill_moves
# 256      Gelson Martins            5
# 568        Vinícius Jr.            5
# 154           R. Mahrez            5
# 1931       M. Fernández            5
# 369            Quaresma            5
# 2990         A. McGeady            5
# 1859         S. Larsson            5
# 1153            E. Elia            5
# 101             Marcelo            5
# 1     Cristiano Ronaldo            5
